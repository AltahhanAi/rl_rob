# %% [markdown]
# # rl_rob: Linear control on Mountain Car
#
# <a href="https://colab.research.google.com/github/<you>/rl_rob/blob/main/examples/notebooks/tilecoded_mountaincar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Linear function approximation on a continuous problem via a discretised state. For multi-tiling tile coding, use `env.gym.tiled` instead.

# %%
# Colab only: install rl_rob first
# !pip install git+https://github.com/<you>/rl_rob.git
# %matplotlib inline

# %%
from rl.linear import *
from env.gym.base import *
from env.gym.discretised import *  # vGymDiscreteS, MountainCar

# %%
vsarsa = vSarsa(env=vGymDiscreteS(**MountainCar), α=.1, ε=0, episodes=500, seed=1, **demoGym).interact()

# %% [markdown]
# Same API as the tabular example, now over a continuous state space.
