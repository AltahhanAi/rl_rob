# %% [markdown]
# # rl_rob: Tabular Sarsa on a gridworld
#
# <a href="https://colab.research.google.com/github/<you>/rl_rob/blob/main/examples/notebooks/sarsa_gridworld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Tabular on-policy control. One construct-and-run call returns the trajectory and the steps-per-episode curve.

# %%
# Colab only: install rl_rob first
# !pip install git+https://github.com/<you>/rl_rob.git
# %matplotlib inline

# %%
from rl.tabular import *        # Sarsa, demo configs
from env.grid.tabular import *  # grid, maze, cliffwalk

# %%
sarsa = Sarsa(env=grid(), α=.8, episodes=50, seed=10, **demoπ).interact()

# %% [markdown]
# Swap `Sarsa` for `Qlearn`, `XSarsa`, or `MCC` and keep everything else the same.
